# %%
import os

DATA_YAML_PATH = "/home/kakani/waymo_project/2_yolo_dataset/data.yaml"

yaml_content = f"""
path: /home/kakani/waymo_project/2_yolo_dataset
train: images/train
val: images/val

names:
  0: VEHICLE
  1: PEDESTRIAN
  2: SIGN
  3: CYCLIST
"""

with open(DATA_YAML_PATH, "w") as f:
    f.write(yaml_content.strip())

print("✅ data.yaml created at:", DATA_YAML_PATH)
# Out:
# ✅ data.yaml created at: /home/kakani/waymo_project/2_yolo_dataset/data.yaml

# %%
print(open(DATA_YAML_PATH).read())
# Out:
# path: /home/kakani/waymo_project/2_yolo_dataset
# train: images/train
# val: images/val
#
# names:
#   0: VEHICLE
#   1: PEDESTRIAN
#   2: SIGN
#   3: CYCLIST
